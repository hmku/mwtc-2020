# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd

# %%
# risk free rate, monthly increments (21 days a month)
dfr = pd.read_csv("risk_free_train.csv", index_col=0)
dfr
# Out:
#             0
# 0    0.029881
# 1    0.033342
# 2    0.033294
# 3    0.029889
# 4    0.035155
# ..        ...
# 115  0.021871
# 116  0.014123
# 117  0.020788
# 118  0.009180
# 119  0.005310
#
# [120 rows x 1 columns]

# %%
# stock prices, daily increments (252 days a year)
txs = list(map(str, list(range(10)))) + ["market_index"] # useful to have
dfp = pd.read_csv("stock_prices_train.csv", index_col=0)
dfp
# Out:
#                0           1           2           3           4           5  \
# 0     100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1     100.212647   98.776261   99.266184   99.052967   98.786495   98.936664
# 2     101.616219  100.071595  100.357080  100.819753   99.648498   98.209640
# 3     100.854665   99.248501   99.476237  100.752015   99.220859   98.123096
# 4      99.707263   98.667138   99.248058   97.880753   98.788507   97.889285
# ...          ...         ...         ...         ...         ...         ...
# 2516  441.913193   34.131963  904.002372  309.557084   85.070133   52.395127
# 2517  438.137581   33.803049  892.630288  307.530146   82.821699   52.607200
# 2518  439.557107   33.421343  883.990617  303.579691   81.029736   53.371531
# 2519  443.022893   33.820313  907.021539  306.605167   86.718141   52.178554
# 2520  445.023602   33.610788  895.615637  304.690532   84.238302   52.152061
#
#                6           7           8           9  market_index
# 0     100.000000  100.000000  100.000000  100.000000    100.000000
# 1      99.732702  100.364210   98.246355  100.075488     99.774815
# 2     101.401583  101.598139  100.166089  100.661240    100.409516
# 3     100.500331   99.621807   98.933229  100.671437     99.785261
# 4      98.233406   99.696244   99.131000   99.775043     99.119263
# ...          ...         ...         ...         ...           ...
# 2516  360.707729  405.149738  155.170640   65.387864    214.647413
# 2517  353.916908  396.449302  152.852827   64.406147    213.057765
# 2518  349.077910  393.161655  151.524617   64.244525    211.198216
# 2519  359.501206  404.769781  156.411473   66.588137    215.793724
# 2520  352.773091  393.365479  154.075947   65.821935    213.858101
#
# [2521 rows x 11 columns]

# %%
# helper function for plotting
def plot(df, *args, cs=False):
    if len(args) == 0:
        args = list(df.columns)
    args = list(map(str, args))
    dft = pd.DataFrame()
    for arg in args:
        dft[arg] = df[arg].cumsum() if cs else df[arg]
    dft.plot(figsize=(15, 10), y=args)

# %%
plot(dfr)

# %%
plot(dfp)

# %% [markdown]
# ## Returns

# %%
# get log returns
dfpr = pd.DataFrame()
for tx in txs:
    dfpr[tx] = np.log(1 + dfp[tx].pct_change())
dfpr
# Out:
#              0         1         2         3         4         5         6  \
# 0          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1     0.002124 -0.012313 -0.007365 -0.009515 -0.012209 -0.010690 -0.002677
# 2     0.013909  0.013029  0.010930  0.017680  0.008688 -0.007376  0.016595
# 3    -0.007523 -0.008259 -0.008816 -0.000672 -0.004301 -0.000882 -0.008928
# 4    -0.011442 -0.005875 -0.002296 -0.028912 -0.004367 -0.002386 -0.022815
# ...        ...       ...       ...       ...       ...       ...       ...
# 2516 -0.008184 -0.017905 -0.008623 -0.009950 -0.041619  0.010146 -0.019040
# 2517 -0.008580 -0.009683 -0.012660 -0.006569 -0.026786  0.004039 -0.019006
# 2518  0.003235 -0.011356 -0.009726 -0.012929 -0.021874  0.014424 -0.013767
# 2519  0.007854  0.011867  0.025720  0.009917  0.067847 -0.022606  0.029422
# 2520  0.004506 -0.006214 -0.012655 -0.006264 -0.029013 -0.000508 -0.018892
#
#              7         8         9  market_index
# 0          NaN       NaN       NaN           NaN
# 1     0.003635 -0.017692  0.000755     -0.002254
# 2     0.012220  0.019352  0.005836      0.006341
# 3    -0.019644 -0.012385  0.000101     -0.006236
# 4     0.000747  0.001997 -0.008944     -0.006697
# ...        ...       ...       ...           ...
# 2516 -0.016621 -0.011034 -0.019554     -0.011282
# 2517 -0.021709 -0.015050 -0.015128     -0.007433
# 2518 -0.008327 -0.008727 -0.002513     -0.008766
# 2519  0.029098  0.031742  0.035830      0.021526
# 2520 -0.028579 -0.015045 -0.011573     -0.009010
#
# [2521 rows x 11 columns]

# %%
# plot cumulative log returns
plot(dfpr, cs=True)

# %% [markdown]
# ## Regression

# %%
# calculate covariance matrix, correlations, betas
# beta(X, Y) = cov(X, Y) / var(Y)
# corr(X, Y) = cov(X, Y) / (sd(X)*sd(Y))
covs = dfpr.cov()
vs = dfpr.var()
betas = covs / vs
sds = pd.DataFrame(np.sqrt(vs)) # sds of tickers, but converted into a dataframe
sdp = sds.dot(sds.T) # sdp[X, Y] = sd(X) * sd(Y)
corrs = covs / sdp

# %%
# correlations
corrs
# Out:
#                      0         1         2         3         4         5  \
# 0             1.000000  0.797205  0.536528  0.815284  0.637714  0.576566
# 1             0.797205  1.000000  0.668629  0.858931  0.741969  0.567782
# 2             0.536528  0.668629  1.000000  0.666550  0.846768  0.243358
# 3             0.815284  0.858931  0.666550  1.000000  0.761069  0.643821
# 4             0.637714  0.741969  0.846768  0.761069  1.000000  0.274662
# 5             0.576566  0.567782  0.243358  0.643821  0.274662  1.000000
# 6             0.725197  0.789129  0.787168  0.833646  0.829435  0.443733
# 7             0.797051  0.863940  0.778002  0.886611  0.843857  0.523511
# 8             0.815009  0.847279  0.726353  0.878759  0.833058  0.550820
# 9             0.691062  0.771331  0.745548  0.794685  0.806076  0.447876
# market_index  0.798901  0.888102  0.829039  0.907393  0.921708  0.491605
#
#                      6         7         8         9  market_index
# 0             0.725197  0.797051  0.815009  0.691062      0.798901
# 1             0.789129  0.863940  0.847279  0.771331      0.888102
# 2             0.787168  0.778002  0.726353  0.745548      0.829039
# 3             0.833646  0.886611  0.878759  0.794685      0.907393
# 4             0.829435  0.843857  0.833058  0.806076      0.921708
# 5             0.443733  0.523511  0.550820  0.447876      0.491605
# 6             1.000000  0.830612  0.812845  0.825229      0.906575
# 7             0.830612  1.000000  0.890858  0.819427      0.941151
# 8             0.812845  0.890858  1.000000  0.808016      0.933683
# 9             0.825229  0.819427  0.808016  1.000000      0.886565
# market_index  0.906575  0.941151  0.933683  0.886565      1.000000

# %%
# betas
betas
# Out:
#                      0         1         2         3         4         5  \
# 0             1.000000  0.609476  0.489663  0.509126  0.328210  0.618090
# 1             1.042758  1.000000  0.798187  0.701598  0.499488  0.796155
# 2             0.587877  0.560101  1.000000  0.456083  0.477513  0.285853
# 3             1.305546  1.051546  0.974141  1.000000  0.627240  1.105227
# 4             1.239080  1.102162  1.501563  0.923451  1.000000  0.572104
# 5             0.537832  0.404917  0.207180  0.375042  0.131863  1.000000
# 6             0.812714  0.676108  0.805109  0.583418  0.478399  0.533096
# 7             1.311131  1.086501  1.168010  0.910772  0.714423  0.923185
# 8             1.133601  0.900971  0.922043  0.763280  0.596347  0.821316
# 9             0.831148  0.709232  0.818356  0.596860  0.498958  0.577459
# market_index  0.721805  0.613446  0.683609  0.511963  0.428595  0.476152
#
#                      6         7         8         9  market_index
# 0             0.647104  0.484536  0.585955  0.574587      0.884231
# 1             0.921042  0.686968  0.796787  0.838867      1.285728
# 2             0.769627  0.518221  0.572195  0.679217      1.005409
# 3             1.191197  0.863090  1.011709  1.058077      1.608244
# 4             1.438052  0.996741  1.163727  1.302233      1.982165
# 5             0.369349  0.296868  0.369411  0.347372      0.507559
# 6             1.000000  0.565874  0.654925  0.768944      1.124497
# 7             1.219206  1.000000  1.053588  1.120752      1.713534
# 8             1.008844  0.753262  1.000000  0.934451      1.437376
# 9             0.885633  0.599116  0.698688  1.000000      1.180171
# market_index  0.730885  0.516923  0.606497  0.666004      1.000000
